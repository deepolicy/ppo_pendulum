# %% [markdown]
# > python -m baselines.run --alg=ppo2 --env=HalfCheetah-v2 --network=mlp --num_timesteps=2e7

# %%
import re
from matplotlib import pyplot as plt

# %%
file = '/media/inksci/file/deepolicy/github-run/baselines-master/print.HalfCheetah-v2.txt'

# %%
with open(file, 'r') as f:
    _str = f.read()
    print(_str[:3000])
# Out:
# Logging to /tmp/openai-2021-03-25-14-44-03-951421
# env_type: mujoco
# Training ppo2 on mujoco:HalfCheetah-v2 with arguments
# {'nsteps': 2048, 'nminibatches': 32, 'lam': 0.95, 'gamma': 0.99, 'noptepochs': 10, 'log_interval': 1, 'ent_coef': 0.0, 'lr': <function mujoco.<locals>.<lambda> at 0x7fa357a5a488>, 'cliprange': 0.2, 'value_network': 'copy', 'network': 'mlp'}
# Stepping environment...
# Done.
# --------------------------------------
# | eplenmean               | 1e+03    |
# | eprewmean               | -417     |
# | fps                     | 433      |
# | loss/approxkl           | 0.00824  |
# | loss/clipfrac           | 0.124    |
# | loss/policy_entropy     | 8.54     |
# | loss/policy_loss        | -0.0207  |
# | loss/value_loss         | 0.365    |
# | misc/explained_variance | -0.505   |
# | misc/nupdates           | 1        |
# | misc/serial_timesteps   | 2.05e+03 |
# | misc/time_elapsed       | 4.73     |
# | misc/total_timesteps    | 2.05e+03 |
# ...

# %%
_str.split('\n')[:10]
# Out:
# ['Logging to /tmp/openai-2021-03-25-14-44-03-951421',
#  'env_type: mujoco',
#  'Training ppo2 on mujoco:HalfCheetah-v2 with arguments ',
#  "{'nsteps': 2048, 'nminibatches': 32, 'lam': 0.95, 'gamma': 0.99, 'noptepochs': 10, 'log_interval': 1, 'ent_coef': 0.0, 'lr': <function mujoco.<locals>.<lambda> at 0x7fa357a5a488>, 'cliprange': 0.2, 'value_network': 'copy', 'network': 'mlp'}",
#  'Stepping environment...',
#  'Done.',
#  '--------------------------------------',
#  '| eplenmean               | 1e+03    |',
#  '| eprewmean               | -417     |',
#  '| fps                     | 433      |']

# %%
_dict = {}
for line in _str.split('\n'):
    match_obj = re.match(r'\| (.*)\s+\| (.*)\s+\|', line, re.M | re.I)
    if match_obj:
        
        k, v = match_obj.group(1), float(match_obj.group(2))
        
        if not k in _dict:
            _dict[k] = []
            
        _dict[k].append(v)

# %%
for k in _dict:
    plt.title(k)
    plt.plot(_dict[k])
    plt.show()
