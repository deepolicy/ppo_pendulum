# %% [markdown]
# Learn Pendulum-v0 with baselines.ppo
#
# -- a failure case.

# %% [markdown]
# > python -m baselines.run --alg=ppo2 --env=Pendulum-v0 --network=mlp --num_timesteps=2e7

# %%
import re
from matplotlib import pyplot as plt

# %%
file = '/media/inksci/file/deepolicy/github-run/baselines-master/print.Pendulum-v0.txt'

# %%
with open(file, 'r') as f:
    _str = f.read()
    print(_str[:3000])
# Out:
# Logging to /tmp/openai-2021-03-25-14-46-56-474657
# env_type: classic_control
# Training ppo2 on classic_control:Pendulum-v0 with arguments
# {'network': 'mlp'}
# ---------------------------------------
# | eplenmean               | 200       |
# | eprewmean               | -1.27e+03 |
# | fps                     | 1.27e+03  |
# | loss/approxkl           | 0.000157  |
# | loss/clipfrac           | 0         |
# | loss/policy_entropy     | 1.42      |
# | loss/policy_loss        | -0.000659 |
# | loss/value_loss         | 5.45e+03  |
# | misc/explained_variance | -0.00162  |
# | misc/nupdates           | 1         |
# | misc/serial_timesteps   | 2.05e+03  |
# | misc/time_elapsed       | 1.61      |
# | misc/total_timesteps    | 2.05e+03  |
# ---------------------------------------
# Stepping environment...
# Done.
# ---------------------------------------
# | eplenmean               | 200       |
# | eprewmean               | -1.21e+03 |
# | fps                     | 1.36e+03  |
# ...

# %%
_str.split('\n')[:10]
# Out:
# ['Logging to /tmp/openai-2021-03-25-14-46-56-474657',
#  'env_type: classic_control',
#  'Training ppo2 on classic_control:Pendulum-v0 with arguments ',
#  "{'network': 'mlp'}",
#  '---------------------------------------',
#  '| eplenmean               | 200       |',
#  '| eprewmean               | -1.27e+03 |',
#  '| fps                     | 1.27e+03  |',
#  '| loss/approxkl           | 0.000157  |',
#  '| loss/clipfrac           | 0         |']

# %%
_dict = {}
for line in _str.split('\n'):
    match_obj = re.match(r'\| (.*)\s+\| (.*)\s+\|', line, re.M | re.I)
    if match_obj:
        
        k, v = match_obj.group(1), float(match_obj.group(2))
        
        if not k in _dict:
            _dict[k] = []
            
        _dict[k].append(v)

# %%
for k in _dict:
    plt.title(k)
    plt.plot(_dict[k])
    plt.show()
