# %% [markdown]
# > python -m baselines.run --alg=ppo2 --env=Humanoid-v2 --network=mlp --num_timesteps=2e7

# %%
import re
from matplotlib import pyplot as plt

# %%
file = '/media/inksci/file/deepolicy/github-run/baselines-master/print.txt'

# %%
with open(file, 'r') as f:
    _str = f.read()
    print(_str[:3000])
# Out:
# Logging to /tmp/openai-2021-03-25-13-27-18-264007
# env_type: mujoco
# Training ppo2 on mujoco:Humanoid-v2 with arguments
# {'nsteps': 2048, 'nminibatches': 32, 'lam': 0.95, 'gamma': 0.99, 'noptepochs': 10, 'log_interval': 1, 'ent_coef': 0.0, 'lr': <function mujoco.<locals>.<lambda> at 0x7ffa48098488>, 'cliprange': 0.2, 'value_network': 'copy', 'network': 'mlp'}
# Stepping environment...
# Done.
# --------------------------------------
# | eplenmean               | 23.4     |
# | eprewmean               | 114      |
# | fps                     | 394      |
# | loss/approxkl           | 0.0189   |
# | loss/clipfrac           | 0.291    |
# | loss/policy_entropy     | 24.1     |
# | loss/policy_loss        | -0.0673  |
# | loss/value_loss         | 0.791    |
# | misc/explained_variance | -0.76    |
# | misc/nupdates           | 1        |
# | misc/serial_timesteps   | 2.05e+03 |
# | misc/time_elapsed       | 5.19     |
# | misc/total_timesteps    | 2.05e+03 |
# --------------------------------------
# Stepping environment...
# Done.
# --------------------------------------
# | eplenmean               | 22.8     |
# | eprewmean               | 111      |
# | fps                     | 423      |
# | loss/approxkl           | 0.0186   |
# | loss/clipfrac           | 0.299    |
# | loss/policy_entropy     | 24       |
# | loss/policy_loss        | -0.078   |
# | loss/value_loss         | 0.442    |
# | misc/explained_variance | -0.342   |
# | misc/nupdates           | 2        |
# | misc/serial_timesteps   | 4.1e+03  |
# | misc/time_elapsed       | 10       |
# | misc/total_timesteps    | 4.1e+03  |
# --------------------------------------
# Stepping environment...
# Done.
# --------------------------------------
# | eplenmean               | 22.2     |
# | eprewmean               | 109      |
# | fps                     | 404      |
# | loss/approxkl           | 0.02     |
# | loss/clipfrac           | 0.315    |
# | loss/policy_entropy     | 24       |
# | loss/policy_loss        | -0.0815  |
# | loss/value_loss         | 0.311    |
# | misc/explained_variance | 0.148    |
# | misc/nupdates           | 3        |
# | misc/serial_timesteps   | 6.14e+03 |
# | misc/time_elapsed       | 15.1     |
# | misc/total_timesteps    | 6.14e+03 |
# --------------------------------------
# Stepping environment...
# Done.
# --------------------------------------
# | eplenmean               | 23.4     |
# | eprewmean               | 115      |
# | fps                     | 395      |
# | loss/approxkl           | 0.0224   |
# | loss/clipfrac           | 0.355    |
# | loss/policy_entropy     | 24       |
# | loss/policy_loss        | -0.0865  |
# | loss/value_loss         | 0.222    |
# | misc/explained_variance | 0.446    |
# | misc/nupdates           | 4        |
# | misc/serial_timesteps   | 8.19e+03 |
# | misc/time_elapsed       | 20.3     |
# | misc/total_timesteps    | 8.19e+03 |
# --------------------------------------
# Stepping environment...
# Done.
# --------------------------------------
# | eplenmean               | 23.3     |
# | eprewmean               | 114      |
# | fps                     | 391

# %%
_str.split('\n')[:10]
# Out:
# ['Logging to /tmp/openai-2021-03-25-13-27-18-264007',
#  'env_type: mujoco',
#  'Training ppo2 on mujoco:Humanoid-v2 with arguments ',
#  "{'nsteps': 2048, 'nminibatches': 32, 'lam': 0.95, 'gamma': 0.99, 'noptepochs': 10, 'log_interval': 1, 'ent_coef': 0.0, 'lr': <function mujoco.<locals>.<lambda> at 0x7ffa48098488>, 'cliprange': 0.2, 'value_network': 'copy', 'network': 'mlp'}",
#  'Stepping environment...',
#  'Done.',
#  '--------------------------------------',
#  '| eplenmean               | 23.4     |',
#  '| eprewmean               | 114      |',
#  '| fps                     | 394      |']

# %%
_dict = {}
for line in _str.split('\n'):
    match_obj = re.match(r'\| (.*)\s+\| (.*)\s+\|', line, re.M | re.I)
    if match_obj:
        
        k, v = match_obj.group(1), float(match_obj.group(2))
        
        if not k in _dict:
            _dict[k] = []
            
        _dict[k].append(v)

# %%
for k in _dict:
    plt.title(k)
    plt.plot(_dict[k])
    plt.show()
