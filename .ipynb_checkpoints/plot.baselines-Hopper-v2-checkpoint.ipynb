# %% [markdown]
# According to the reward change during learning.
#
# It is a bad performance for PPO to learning Hopper-v2.

# %% [markdown]
# > python -m baselines.run --alg=ppo2 --env=Hopper-v2 --network=mlp --num_timesteps=2e7

# %%
import re
from matplotlib import pyplot as plt

# %%
file = '/media/inksci/file/deepolicy/github-run/baselines-master/print.Hopper-v2.txt'

# %%
with open(file, 'r') as f:
    _str = f.read()
    print(_str[:3000])
# Out:
# Logging to /tmp/openai-2021-03-25-14-45-29-150611
# env_type: mujoco
# Training ppo2 on mujoco:Hopper-v2 with arguments
# {'nsteps': 2048, 'nminibatches': 32, 'lam': 0.95, 'gamma': 0.99, 'noptepochs': 10, 'log_interval': 1, 'ent_coef': 0.0, 'lr': <function mujoco.<locals>.<lambda> at 0x7fa60898a488>, 'cliprange': 0.2, 'value_network': 'copy', 'network': 'mlp'}
# Stepping environment...
# Done.
# --------------------------------------
# | eplenmean               | 19.9     |
# | eprewmean               | 16.4     |
# | fps                     | 360      |
# | loss/approxkl           | 0.00607  |
# | loss/clipfrac           | 0.077    |
# | loss/policy_entropy     | 4.26     |
# | loss/policy_loss        | -0.0133  |
# | loss/value_loss         | 0.926    |
# | misc/explained_variance | -1.17    |
# | misc/nupdates           | 1        |
# | misc/serial_timesteps   | 2.05e+03 |
# | misc/time_elapsed       | 5.68     |
# | misc/total_timesteps    | 2.05e+03 |
# ...

# %%
_str.split('\n')[:10]
# Out:
# ['Logging to /tmp/openai-2021-03-25-14-45-29-150611',
#  'env_type: mujoco',
#  'Training ppo2 on mujoco:Hopper-v2 with arguments ',
#  "{'nsteps': 2048, 'nminibatches': 32, 'lam': 0.95, 'gamma': 0.99, 'noptepochs': 10, 'log_interval': 1, 'ent_coef': 0.0, 'lr': <function mujoco.<locals>.<lambda> at 0x7fa60898a488>, 'cliprange': 0.2, 'value_network': 'copy', 'network': 'mlp'}",
#  'Stepping environment...',
#  'Done.',
#  '--------------------------------------',
#  '| eplenmean               | 19.9     |',
#  '| eprewmean               | 16.4     |',
#  '| fps                     | 360      |']

# %%
_dict = {}
for line in _str.split('\n'):
    match_obj = re.match(r'\| (.*)\s+\| (.*)\s+\|', line, re.M | re.I)
    if match_obj:
        
        k, v = match_obj.group(1), float(match_obj.group(2))
        
        if not k in _dict:
            _dict[k] = []
            
        _dict[k].append(v)

# %%
for k in _dict:
    plt.title(k)
    plt.plot(_dict[k])
    plt.show()
